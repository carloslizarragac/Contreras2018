# %%
# Leer archivo csv, separado por ";"
df_dist <- read.csv(file="corral-DAG.csv", header=TRUE, sep=";", stringsAsFactors=FALSE)

# %%
str(df_dist)
# Out:
# 'data.frame':	849 obs. of  170 variables:
#  $ filename                       : chr  "" "2017-11-05T113000_AIU-0962.ghg" "2017-11-05T120000_AIU-0962.ghg" "2017-11-05T123000_AIU-0962.ghg" ...
#  $ date                           : chr  "[yyyy-mm-dd]" "2017-11-05" "2017-11-05" "2017-11-05" ...
#  $ time                           : chr  "[HH:MM]" "12:00:00" "12:30:00" "13:00:00" ...
#  $ DOY                            : chr  "[ddd.ddd]" "309.499" "309.52" "309.541" ...
#  $ daytime                        : chr  "[1=daytime]" "1" "1" "1" ...
#  $ file_records                   : chr  "[#]" "18000" "18000" "18000" ...
#  $ used_records                   : chr  "[#]" "18000" "18000" "18000" ...
#  $ Tau                            : chr  "[kg+1m-1s-2]" "1.47E-02" "0.515316295" "0.337491395" ...
#  $ qc_Tau                         : chr  "[#]" "0" "1" "1" ...
#  $ H                              : chr  "[W+1m-2]" "147.37" "176.01" "97" ...
#  $ qc_H                           : chr  "[#]" "0" "1" "0" ...
#  $ LE                             : chr  "[W+1m-2]" "61" "" "" ...
#  $ qc_LE                          : chr  "[#]" "0" "2" "1" ...
#  $ co2_flux                       : chr  "[\x8c\xb5mol+1s-1m-2]" "21.07" "-2.28" "11.53" ...
#  $ qc_co2_flux                    : chr  "[#]" "0" "2" "1" ...
#  $ h2o_flux                       : chr  "[mmol+1s-1m-2]" "1.4" "-3" "12.79" ...
#  $ qc_h2o_flux                    : chr  "[#]" "0" "2" "1" ...
#  $ ch4_flux                       : chr  "[\x8c\xb5mol+1s-1m-2]" "0.63" "0.03" "0.33" ...
#  $ qc_ch4_flux                    : chr  "[#]" "0" "1" "1" ...
#  $ H_strg                         : chr  "[W+1m-2]" "-9999" "1.597930958" "-3.028552815" ...
#  $ LE_strg                        : chr  "[W+1m-2]" "-9999" "-4.21970937" "-8.638805846" ...
#  $ co2_strg                       : chr  "[\x8c\xb5mol+1s-1m-2]" "-9999" "-0.110614687" "9.42E-02" ...
#  $ h2o_strg                       : chr  "[mmol+1s-1m-2]" "-9999" "-9.67E-02" "-0.197715494" ...
#  $ ch4_strg                       : chr  "[\x8c\xb5mol+1s-1m-2]" "-9999" "-6.26E-03" "6.02E-04" ...
#  $ co2_v.adv                      : chr  "[\x8c\xb5mol+1s-1m-2]" "5.16E-11" "2.06E-11" "6.91E-11" ...
#  $ h2o_v.adv                      : chr  "[mmol+1s-1m-2]" "1.74E-12" "6.52E-13" "1.88E-12" ...
#  $ ch4_v.adv                      : chr  "[\x8c\xb5mol+1s-1m-2]" "2.66E-13" "1.04E-13" "3.51E-13" ...
#  $ co2_molar_density              : chr  "[mmol+1m-3]" "15.05201883" "14.96423518" "14.94104893" ...
#  $ co2_mole_fraction              : chr  "[\x8c\xb5mol+1mol_a-1]" "392.9012313" "391.944324" "392.7576096" ...
#  $ co2_mixing_ratio               : chr  "[\x8c\xb5mol+1mol_d-1]" "398.1722773" "396.8662249" "397.0037739" ...
#  $ co2_time_lag                   : chr  "[s]" "0.2" "0.2" "0.1" ...
#  $ co2_def_timelag                : chr  "[1=default]" "1" "1" "0" ...
#  $ h2o_molar_density              : chr  "[mmol+1m-3]" "507.1508446" "473.4987883" "406.8727886" ...
#  $ h2o_mole_fraction              : chr  "[mmol+1mol_a-1]" "13.23810404" "12.40191432" "10.69552644" ...
#  $ h2o_mixing_ratio               : chr  "[mmol+1mol_d-1]" "13.41570251" "12.55765326" "10.81115746" ...
#  $ h2o_time_lag                   : chr  "[s]" "0.2" "0.2" "0.2" ...
#  $ h2o_def_timelag                : chr  "[1=default]" "0" "1" "0" ...
#  $ ch4_molar_density              : chr  "[mmol+1m-3]" "7.76E-02" "7.54E-02" "7.60E-02" ...
#  $ ch4_mole_fraction              : chr  "[\x8c\xb5mol+1mol_a-1]" "1.979581748" "1.926534126" "1.931627342" ...
#  $ ch4_mixing_ratio               : chr  "[\x8c\xb5mol+1mol_d-1]" "2.006139227" "1.950726874" "1.95251047" ...
#  $ ch4_time_lag                   : chr  "[s]" "-0.2" "0" "0" ...
#  $ ch4_def_timelag                : chr  "[1=default]" "0" "1" "1" ...
#  $ sonic_temperature              : chr  "[K]" "301.9796451" "302.9433622" "303.3264067" ...
#  $ air_temperature                : chr  "[K]" "305.3981761" "305.8690477" "304.9784248" ...
#  $ air_pressure                   : chr  "[Pa]" "98588.22571" "98534.13448" "98478.24583" ...
#  $ air_density                    : chr  "[kg+1m-3]" "1.119017234" "1.117036402" "1.120388879" ...
#  $ air_heat_capacity              : chr  "[J+1kg-1K-1]" "1013.114246" "1012.667583" "1011.69883" ...
#  $ air_molar_volume               : chr  "[m+3mol-1]" "2.58E-02" "2.58E-02" "2.57E-02" ...
#  $ ET                             : chr  "[mm+1hour-1]" "9.05E-02" "-0.194482038" "0.828849175" ...
#  $ water_vapor_density            : chr  "[kg+1m-3]" "9.26E-03" "8.66E-03" "7.49E-03" ...
#  $ e                              : chr  "[Pa]" "1305.471274" "1222.339685" "1053.559213" ...
#  $ es                             : chr  "[Pa]" "4808.455293" "4937.686381" "4695.739694" ...
#  $ specific_humidity              : chr  "[kg+1kg-1]" "8.28E-03" "7.75E-03" "6.68E-03" ...
#  $ RH                             : chr  "[%]" "27.14949385" "24.75531232" "22.43649097" ...
#  $ VPD                            : chr  "[Pa]" "3502.984019" "3715.346696" "3642.180482" ...
#  $ Tdew                           : chr  "[K]" "284.0770894" "283.0910361" "280.8923474" ...
#  $ u_unrot                        : chr  "[m+1s-1]" "0.941139302" "6.36E-02" "-0.458602991" ...
#  $ v_unrot                        : chr  "[m+1s-1]" "-0.333682896" "5.72E-02" "-0.422744366" ...
#  $ w_unrot                        : chr  "[m+1s-1]" "0.108432528" "0.155642277" "0.136340997" ...
#  $ u_rot                          : chr  "[m+1s-1]" "1.004412801" "0.17758483" "0.638449974" ...
#  $ v_rot                          : chr  "[m+1s-1]" "4.41E-14" "-1.14E-14" "4.47E-14" ...
#  $ w_rot                          : chr  "[m+1s-1]" "3.43E-15" "1.38E-15" "4.63E-15" ...
#  $ wind_speed                     : chr  "[m+1s-1]" "1" "0.18" "0.64" ...
#  $ max_wind_speed                 : chr  "[m+1s-1]" "3.25" "5.73" "4.04" ...
#  $ wind_dir                       : chr  "[deg_from_north]" "98.03" "277.33" "323" ...
#  $ yaw                            : chr  "[deg]" "340.4779326" "41.97349226" "222.6701407" ...
#  $ pitch                          : chr  "[deg]" "6.197509296" "61.21574531" "12.33047338" ...
#  $ roll                           : chr  "[deg]" "-9999" "-9999" "-9999" ...
#  $ u.                             : chr  "[m+1s-1]" "0.11" "0.68" "0.55" ...
#  $ TKE                            : chr  "[m+2s-2]" "0.543483568" "0.952312411" "1.13804528" ...
#  $ L                              : chr  "[m]" "-0.880402932" "-153.7860491" "-147.1336977" ...
#  $ X.z.d..L                       : chr  "[#]" "-3.08949448" "-1.77E-02" "-1.85E-02" ...
#  $ bowen_ratio                    : chr  "[#]" "2.415849062" "-1.343398061" "0.17356261" ...
#  $ T.                             : chr  "[K]" "1.135318227" "0.229090183" "0.155920311" ...
#  $ model                          : chr  "[0=KJ/1=KM/2=HS]" "1" "0" "0" ...
#  $ x_peak                         : chr  "[m]" "7.762777686" "21.66600212" "31.59164198" ...
#  $ x_offset                       : chr  "[m]" "4" "-3.287899409" "-4.794153552" ...
#  $ x_10.                          : chr  "[m]" "6" "7.437237416" "10.84438839" ...
#  $ x_30.                          : chr  "[m]" "10" "18.51977274" "27.00406041" ...
#  $ x_50.                          : chr  "[m]" "15" "28.24382196" "41.18289598" ...
#  $ x_70.                          : chr  "[m]" "23" "39.61236189" "57.75959718" ...
#  $ x_90.                          : chr  "[m]" "51" "59.34653642" "86.53440175" ...
#  $ un_Tau                         : chr  "[kg+1m-1s-2]" "1.45E-02" "0.492103862" "0.331703335" ...
#  $ Tau_scf                        : chr  "[#]" "1.012680848" "1.047169783" "1.017449508" ...
#  $ un_H                           : chr  "[W+1m-2]" "149.4695" "162.3666238" "129.7335196" ...
#  $ H_scf                          : chr  "[#]" "1.015438318" "1.03801763" "1.018368672" ...
#  $ un_LE                          : chr  "[W+1m-2]" "57.54561095" "-121.4171481" "527.3947342" ...
#  $ LE_scf                         : chr  "[#]" "1.060084649" "1.079093912" "1.059687287" ...
#  $ un_co2_flux                    : chr  "[\x8c\xb5mol+1s-1m-2]" "19.87108978" "-2.109568268" "10.8774705" ...
#  $ co2_scf                        : chr  "[#]" "1.060084649" "1.079093912" "1.059687287" ...
#  $ un_h2o_flux                    : chr  "[mmol+1s-1m-2]" "1.317581279" "-2.781283437" "12.07043105" ...
#  $ h2o_scf                        : chr  "[#]" "1.060084649" "1.079093912" "1.059687287" ...
#  $ un_ch4_flux                    : chr  "[\x8c\xb5mol+1s-1m-2]" "0.522611458" "-1.39E-02" "0.237354114" ...
#  $ ch4_scf                        : chr  "[#]" "1.124495678" "1.153220097" "1.126885007" ...
#  $ spikes_hf                      : chr  "8u/v/w/ts/co2/h2o/ch4/none" "800000009" "800000009" "800000009" ...
#  $ amplitude_resolution_hf        : chr  "8u/v/w/ts/co2/h2o/ch4/none" "800000009" "800000009" "800000009" ...
#  $ drop_out_hf                    : chr  "8u/v/w/ts/co2/h2o/ch4/none" "800000009" "800000009" "800000009" ...
#  $ absolute_limits_hf             : chr  "8u/v/w/ts/co2/h2o/ch4/none" "800000009" "800000009" "800000009" ...
#  $ skewness_kurtosis_hf           : chr  "8u/v/w/ts/co2/h2o/ch4/none" "800001019" "800001019" "800001019" ...
#   [list output truncated]

# %%
# Eliminar segundo renglón
df_dist <- df_dist[-c(1),]

# %%
# verificar estructura
head(df_dist)
# Out:
#   filename                       date       time     DOY     daytime
# 2 2017-11-05T113000_AIU-0962.ghg 2017-11-05 12:00:00 309.499 1
# 3 2017-11-05T120000_AIU-0962.ghg 2017-11-05 12:30:00 309.52  1
# 4 2017-11-05T123000_AIU-0962.ghg 2017-11-05 13:00:00 309.541 1
# 5 2017-11-05T130000_AIU-0962.ghg 2017-11-05 13:30:00 309.562 1
# 6 2017-11-05T133000_AIU-0962.ghg 2017-11-05 14:00:00 309.583 1
# 7 2017-11-05T140000_AIU-0962.ghg 2017-11-05 14:30:00 309.604 1
#   file_records used_records Tau         qc_Tau H      ⋯ flowrate_mean
# 2 18000        18000        1.47E-02    0      147.37 ⋯ 2.91E-04
# 3 18000        18000        0.515316295 1      176.01 ⋯ 2.91E-04
# 4 18000        18000        0.337491395 1      97     ⋯ 2.93E-04
# 5 18000        18000        0.111201142 1      173.22 ⋯ 2.93E-04
# 6 18000        18000        0.145200585 0      111.13 ⋯ 2.94E-04
# 7 18000        18000        0.210068361 0      182.67 ⋯ 2.94E-04
#   ch4_mean    rssi_77_mean ch4_aux.1_mean ch4_aux.2_mean ch4_aux.3_mean
# 2 1.968519657 76.80017714  -607.1615148   -1.08E-05      2.09E-06
# 3 1.916582733 76.76769683  -999.9000244   -6.94E-06      7.14E-06
# 4 1.923094952 76.28478178  -999.9000244   -3.36E-06      5.66E-06
# 5 1.912438849 76.04075584  -999.9000244   -1.60E-06      6.21E-06
# 6 1.925369264 76.01727104  -999.9000244   -1.99E-06      4.57E-06
# 7 1.911490898 80.08074272  -999.9000244   -1.03E-06      5.51E-06
#   ch4_aux.4_mean ch4_tc_1_mean ch4_tc_2_mean ch4_tc_3_mean
# 2 -5.38E-05      9999.990234   9999.990234   9999.990234
# 3 -3.09E-05      9999.990234   9999.990234   9999.990234
# 4 -1.13E-05      9999.990234   9999.990234   9999.990234
# 5 -8.10E-06      9999.990234   9999.990234   9999.990234
# 6 -7.62E-06      9999.990234   9999.990234   9999.990234
# 7 -9.23E-06      9999.990234   9999.990234   9999.990234

# %%
# Nombres de columnas
names(df_dist)
# Out:
#   [1] "filename"                        "date"
#   [3] "time"                            "DOY"
#   [5] "daytime"                         "file_records"
#   [7] "used_records"                    "Tau"
#   [9] "qc_Tau"                          "H"
#  [11] "qc_H"                            "LE"
#  [13] "qc_LE"                           "co2_flux"
#  [15] "qc_co2_flux"                     "h2o_flux"
#  [17] "qc_h2o_flux"                     "ch4_flux"
#  [19] "qc_ch4_flux"                     "H_strg"
#  [21] "LE_strg"                         "co2_strg"
#  [23] "h2o_strg"                        "ch4_strg"
#  [25] "co2_v.adv"                       "h2o_v.adv"
#  [27] "ch4_v.adv"                       "co2_molar_density"
#  [29] "co2_mole_fraction"               "co2_mixing_ratio"
#  [31] "co2_time_lag"                    "co2_def_timelag"
#  [33] "h2o_molar_density"               "h2o_mole_fraction"
#  [35] "h2o_mixing_ratio"                "h2o_time_lag"
#  [37] "h2o_def_timelag"                 "ch4_molar_density"
#  [39] "ch4_mole_fraction"               "ch4_mixing_ratio"
#  [41] "ch4_time_lag"                    "ch4_def_timelag"
#  [43] "sonic_temperature"               "air_temperature"
#  [45] "air_pressure"                    "air_density"
#  [47] "air_heat_capacity"               "air_molar_volume"
#  [49] "ET"                              "water_vapor_density"
#  [51] "e"                               "es"
#  [53] "specific_humidity"               "RH"
#  [55] "VPD"                             "Tdew"
#  [57] "u_unrot"                         "v_unrot"
#  [59] "w_unrot"                         "u_rot"
#  [61] "v_rot"                           "w_rot"
#  [63] "wind_speed"                      "max_wind_speed"
#  [65] "wind_dir"                        "yaw"
#  [67] "pitch"                           "roll"
#  [69] "u."                              "TKE"
#  [71] "L"                               "X.z.d..L"
#  [73] "bowen_ratio"                     "T."
#  [75] "model"                           "x_peak"
#  [77] "x_offset"                        "x_10."
#  [79] "x_30."                           "x_50."
#  [81] "x_70."                           "x_90."
#  [83] "un_Tau"                          "Tau_scf"
#  [85] "un_H"                            "H_scf"
#  [87] "un_LE"                           "LE_scf"
#  [89] "un_co2_flux"                     "co2_scf"
#  [91] "un_h2o_flux"                     "h2o_scf"
#  [93] "un_ch4_flux"                     "ch4_scf"
#  [95] "spikes_hf"                       "amplitude_resolution_hf"
#  [97] "drop_out_hf"                     "absolute_limits_hf"
#  [99] "skewness_kurtosis_hf"            "skewness_kurtosis_sf"
# [101] "discontinuities_hf"              "discontinuities_sf"
# [103] "timelag_hf"                      "timelag_sf"
# [105] "attack_angle_hf"                 "non_steady_wind_hf"
# [107] "u_spikes"                        "v_spikes"
# [109] "w_spikes"                        "ts_spikes"
# [111] "co2_spikes"                      "h2o_spikes"
# [113] "ch4_spikes"                      "head_detect_LI.7200"
# [115] "t_out_LI.7200"                   "t_in_LI.7200"
# [117] "aux_in_LI.7200"                  "delta_p_LI.7200"
# [119] "chopper_LI.7200"                 "detector_LI.7200"
# [121] "pll_LI.7200"                     "sync_LI.7200"
# [123] "not_ready_LI.7700"               "no_signal_LI.7700"
# [125] "re_unlocked_LI.7700"             "bad_temp_LI.7700"
# [127] "laser_temp_unregulated_LI.7700"  "block_temp_unregulated_LI.7700"
# [129] "motor_spinning_LI.7700"          "pump_on_LI.7700"
# [131] "top_heater_on_LI.7700"           "bottom_heater_on_LI.7700"
# [133] "calibrating_LI.7700"             "motor_failure_LI.7700"
# [135] "bad_aux_tc1_LI.7700"             "bad_aux_tc2_LI.7700"
# [137] "bad_aux_tc3_LI.7700"             "box_connected_LI.7700"
# [139] "mean_value_RSSI_LI.7200"         "u_var"
# [141] "v_var"                           "w_var"
# [143] "ts_var"                          "co2_var"
# [145] "h2o_var"                         "ch4_var"
# [147] "w.ts_cov"                        "w.co2_cov"
# [149] "w.h2o_cov"                       "w.ch4_cov"
# [151] "co2_mean"                        "h2o_mean"
# [153] "air_p_mean"                      "co2_mean.1"
# [155] "h2o_mean.1"                      "dew_point_mean"
# [157] "avg_signal_strength_7200_mean"   "co2_signal_strength_7200_mean"
# [159] "h2o_signal_strength_7200_mean"   "delta_signal_strength_7200_mean"
# [161] "flowrate_mean"                   "ch4_mean"
# [163] "rssi_77_mean"                    "ch4_aux.1_mean"
# [165] "ch4_aux.2_mean"                  "ch4_aux.3_mean"
# [167] "ch4_aux.4_mean"                  "ch4_tc_1_mean"
# [169] "ch4_tc_2_mean"                   "ch4_tc_3_mean"

# %%
# La velocidad del viento, vel max y dirección estan en columnas X, X.1, X.2
# Convertir columnas a numérico
require(dplyr)
df_Wind <- subset(df_dist, select=c("date", "time", "wind_speed", "wind_dir"))
names(df_Wind) <- c("date", "hours", "spd", "dir")
df_Wind <- df_Wind[complete.cases(df_Wind), ]
#df_Wind[] <- lapply(df_Wind, as.numeric)
df_Wind$Date <- as.POSIXct(paste(df_Wind$date, df_Wind$hours), format="%Y-%m-%d %H:%M")
#df_Wind$time <- with(df_Wind, as.POSIXct(paste(date, hours)))
df_Wind$spd <- as.numeric(df_Wind$spd)
df_Wind$dir <- as.numeric(df_Wind$dir)
head(df_Wind)
# Out:
# Loading required package: dplyr
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#   date       hours    spd  dir    Date
# 2 2017-11-05 12:00:00 1.00  98.03 2017-11-05 12:00:00
# 3 2017-11-05 12:30:00 0.18 277.33 2017-11-05 12:30:00
# 4 2017-11-05 13:00:00 0.64 323.00 2017-11-05 13:00:00
# 5 2017-11-05 13:30:00 0.81 278.90 2017-11-05 13:30:00
# 6 2017-11-05 14:00:00 1.13 273.00 2017-11-05 14:00:00
# 7 2017-11-05 14:30:00 1.55 267.74 2017-11-05 14:30:00

# %%
head(df_Wind)
str(df_Wind)
# Out:
#   date       hours    spd  dir    Date
# 2 2017-11-05 12:00:00 1.00  98.03 2017-11-05 12:00:00
# 3 2017-11-05 12:30:00 0.18 277.33 2017-11-05 12:30:00
# 4 2017-11-05 13:00:00 0.64 323.00 2017-11-05 13:00:00
# 5 2017-11-05 13:30:00 0.81 278.90 2017-11-05 13:30:00
# 6 2017-11-05 14:00:00 1.13 273.00 2017-11-05 14:00:00
# 7 2017-11-05 14:30:00 1.55 267.74 2017-11-05 14:30:00
# 'data.frame':	848 obs. of  5 variables:
#  $ date : chr  "2017-11-05" "2017-11-05" "2017-11-05" "2017-11-05" ...
#  $ hours: chr  "12:00:00" "12:30:00" "13:00:00" "13:30:00" ...
#  $ spd  : num  1 0.18 0.64 0.81 1.13 1.55 1.45 2.1 2.2 2.75 ...
#  $ dir  : num  98 277 323 279 273 ...
#  $ Date : POSIXct, format: "2017-11-05 12:00:00" "2017-11-05 12:30:00" ...

# %%
# Definiendo la fecha a partir del 2017-01-01
# today<-as.POSIXct('2017-11-05 00:00:00 EST')
# Conversión a segundos: Inicio + DOY*86400 + Hour*3600
# df_Wind$Date <- today + (df_Wind$DOY-1.0)*86400

# %%
data <- df_Wind
head(data)
str(data)
# Out:
#   date       hours    spd  dir    Date
# 2 2017-11-05 12:00:00 1.00  98.03 2017-11-05 12:00:00
# 3 2017-11-05 12:30:00 0.18 277.33 2017-11-05 12:30:00
# 4 2017-11-05 13:00:00 0.64 323.00 2017-11-05 13:00:00
# 5 2017-11-05 13:30:00 0.81 278.90 2017-11-05 13:30:00
# 6 2017-11-05 14:00:00 1.13 273.00 2017-11-05 14:00:00
# 7 2017-11-05 14:30:00 1.55 267.74 2017-11-05 14:30:00
# 'data.frame':	848 obs. of  5 variables:
#  $ date : chr  "2017-11-05" "2017-11-05" "2017-11-05" "2017-11-05" ...
#  $ hours: chr  "12:00:00" "12:30:00" "13:00:00" "13:30:00" ...
#  $ spd  : num  1 0.18 0.64 0.81 1.13 1.55 1.45 2.1 2.2 2.75 ...
#  $ dir  : num  98 277 323 279 273 ...
#  $ Date : POSIXct, format: "2017-11-05 12:00:00" "2017-11-05 12:30:00" ...

# %%
require(ggplot2)
require(RColorBrewer)
# Out:
# Loading required package: ggplot2
# Loading required package: RColorBrewer

# %%
plot.windrose <- function(data,
                      spd,
                      dir,
                      spdres = 0.5,
                      dirres = 30,
                      spdmin = 1,
                      spdmax = 20,
                      spdseq = NULL,
                      palette = "RdPu",
                      countmax = NA,
                      debug = 0){


# Look to see what data was passed in to the function
  if (is.numeric(spd) & is.numeric(dir)){
    # assume that we've been given vectors of the speed and direction vectors
    data <- data.frame(spd = spd,
                       dir = dir)
    spd = "spd"
    dir = "dir"
  } else if (exists("data")){
    # Assume that we've been given a data frame, and the name of the speed 
    # and direction columns. This is the format we want for later use.    
  }  

  # Tidy up input data ----
  n.in <- NROW(data)
  dnu <- (is.na(data[[spd]]) | is.na(data[[dir]]))
  data[[spd]][dnu] <- NA
  data[[dir]][dnu] <- NA

  # figure out the wind speed bins ----
  if (missing(spdseq)){
    spdseq <- seq(spdmin,spdmax,spdres)
  } else {
    if (debug >0){
      cat("Using custom speed bins \n")
    }
  }
  # get some information about the number of bins, etc.
  n.spd.seq <- length(spdseq)
  n.colors.in.range <- n.spd.seq - 1

  # create the color map
  spd.colors <- colorRampPalette(brewer.pal(min(max(3,
                                                    n.colors.in.range),
                                                min(9,
                                                    n.colors.in.range)),                                               
                                            palette))(n.colors.in.range)

  if (max(data[[spd]],na.rm = TRUE) > spdmax){    
    spd.breaks <- c(spdseq,
                    max(data[[spd]],na.rm = TRUE))
    spd.labels <- c(paste(c(spdseq[1:n.spd.seq-1]),
                          '-',
                          c(spdseq[2:n.spd.seq])),
                    paste(spdmax,
                          "-",
                          max(data[[spd]],na.rm = TRUE)))
    spd.colors <- c(spd.colors, "grey50")
  } else{
    spd.breaks <- spdseq
    spd.labels <- paste(c(spdseq[1:n.spd.seq-1]),
                        '-',
                        c(spdseq[2:n.spd.seq]))    
  }
  data$spd.binned <- cut(x = data[[spd]],
                         breaks = spd.breaks,
                         labels = spd.labels,
                         ordered_result = TRUE)
  # clean up the data
  data. <- na.omit(data)

  # figure out the wind direction bins
  dir.breaks <- c(-dirres/2,
                  seq(dirres/2, 360-dirres/2, by = dirres),
                  360+dirres/2)  
  dir.labels <- c(paste(360-dirres/2,"-",dirres/2),
                  paste(seq(dirres/2, 360-3*dirres/2, by = dirres),
                        "-",
                        seq(3*dirres/2, 360-dirres/2, by = dirres)),
                  paste(360-dirres/2,"-",dirres/2))
  # assign each wind direction to a bin
  dir.binned <- cut(data[[dir]],
                    breaks = dir.breaks,
                    ordered_result = TRUE)
  levels(dir.binned) <- dir.labels
  data$dir.binned <- dir.binned

  # Run debug if required ----
  if (debug>0){    
    cat(dir.breaks,"\n")
    cat(dir.labels,"\n")
    cat(levels(dir.binned),"\n")       
  }  

  # deal with change in ordering introduced somewhere around version 2.2
  if(packageVersion("ggplot2") > "2.2"){    
    cat("Hadley broke my code\n")
    data$spd.binned = with(data, factor(spd.binned, levels = rev(levels(spd.binned))))
    spd.colors = rev(spd.colors)
  }

  # create the plot ----
  p.windrose <- ggplot(data = data,
                       aes(x = dir.binned,
                           fill = spd.binned)) +
    geom_bar() + 
    scale_x_discrete(drop = FALSE,
                     labels = waiver()) +
    coord_polar(start = -((dirres/2)/360) * 2*pi) +
    scale_fill_manual(name = "Velocidad (m/s)", 
                      values = spd.colors,
                      drop = FALSE) +
    #theme_bw() +
    theme(axis.title.x = element_blank(),
          #panel.border = element_rect(colour = "blank"),
          panel.grid.major = element_line(colour="grey65"))

  # adjust axes if required
  if (!is.na(countmax)){
    p.windrose <- p.windrose +
      ylim(c(0,countmax))
  }

  # print the plot
  print(p.windrose)  

  # return the handle to the wind rose
  return(p.windrose)
}

# %%
# try the default settings
p1 <- plot.windrose(spd = df_Wind$spd,
                   dir = df_Wind$dir)
# Out:
# Hadley broke my code
# plot without title

# %%
p2 <- plot.windrose(data=df_Wind, spd = df_Wind$spd,
                   dir = df_Wind$dir,
#                   spdseq = c(0,0.5,1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6)) +
                     spdseq = c(0,1,2,3,4,5,6)) +
                   ggtitle("Vientos - Metano en Corrales") +
                   ylab("Frecuencia") # for the main title
p2
# Out:
# Hadley broke my code
# plot without title
# plot without title

# %%
# Mixing ratios
require(dplyr)
df_gases <- subset(df_dist, select=c("date", "time", "co2_flux", "co2_mixing_ratio", 
                                        "co2_time_lag", "ch4_flux", "ch4_mixing_ratio", 
                                        "ch4_time_lag"))
names(df_gases) <- c("date", "hours", "co2flux", "co2mix", "co2tlag", "ch4flux", "ch4mix", "ch4tlag")
df_gases <- df_gases[complete.cases(df_gases), ]
#df_Wind[] <- lapply(df_Wind, as.numeric)
df_gases$Date <- as.POSIXct(paste(df_gases$date, df_gases$hours), format="%Y-%m-%d %H:%M")
#df_Wind$time <- with(df_Wind, as.POSIXct(paste(date, hours)))
df_gases$co2flux <- as.numeric(df_gases$co2flux)
df_gases$co2mix <- as.numeric(df_gases$co2mix)
df_gases$co2tlag <- as.numeric(df_gases$co2tlag)
df_gases$ch4flux <- as.numeric(df_gases$ch4flux)
df_gases$ch4mix <- as.numeric(df_gases$ch4mix)
df_gases$ch4tlag <- as.numeric(df_gases$ch4tlag)
head(df_gases)
# Out:
#   date       hours    co2flux co2mix   co2tlag ch4flux ch4mix   ch4tlag
# 2 2017-11-05 12:00:00 21.07   398.1723 0.2     0.63    2.006139 -0.2
# 3 2017-11-05 12:30:00 -2.28   396.8662 0.2     0.03    1.950727  0.0
# 4 2017-11-05 13:00:00 11.53   397.0038 0.1     0.33    1.952510  0.0
# 5 2017-11-05 13:30:00  2.01   397.2686 0.1     0.06    1.938722  0.0
# 6 2017-11-05 14:00:00  1.96   397.4199 0.1     0.01    1.954108 -0.1
# 7 2017-11-05 14:30:00  2.45   396.7849 0.1     0.02    1.939585 -0.1
#   Date
# 2 2017-11-05 12:00:00
# 3 2017-11-05 12:30:00
# 4 2017-11-05 13:00:00
# 5 2017-11-05 13:30:00
# 6 2017-11-05 14:00:00
# 7 2017-11-05 14:30:00

# %%
#ggplot(df_gases, aes(Date, ch4flux)) + xlab("Time") + ylab("CH4 flux")
ggplot() + # geom_line(data=df_gases, aes(x=Date, y=co2flux), color="brown", na.rm=TRUE) +
            geom_point(data=df_gases, aes(x=Date, y=ch4flux), color="brown", na.rm=TRUE) +
           ggtitle("CH4 Flux") +
           xlab("Date") + ylab("Flux")
# Out:
# plot without title

# %%
ggplot(df_gases, aes(co2flux, ch4flux)) +
           geom_point(na.rm=TRUE, color="blue", size=1) + 
           ggtitle("CO2/CH4 Flux") +
           xlab("CO2 Flux") + ylab("CH4 Flux")
# Out:
# plot without title

# %%
# Opción 
# Calcular Vientos diurnos
# 
#require(dplyr)
#require(lubridate)
#result <- with( df_Wind , df_Wind[ hour(df_Wind$Date) >= 6 & hour(df_Wind$Date) < 18 , ])
#head(result)

# %%
data <- result
head(data)
str(data)

# %%
plot.windrose <- function(data,
                      spd,
                      dir,
                      spdres = 1,
                      dirres = 30,
                      spdmin = 1,
                      spdmax = 20,
                      spdseq = NULL,
                      palette = "RdPu",
                      countmax = NA,
                      debug = 0){


# Look to see what data was passed in to the function
  if (is.numeric(spd) & is.numeric(dir)){
    # assume that we've been given vectors of the speed and direction vectors
    data <- data.frame(spd = spd,
                       dir = dir)
    spd = "spd"
    dir = "dir"
  } else if (exists("data")){
    # Assume that we've been given a data frame, and the name of the speed 
    # and direction columns. This is the format we want for later use.    
  }  

  # Tidy up input data ----
  n.in <- NROW(data)
  dnu <- (is.na(data[[spd]]) | is.na(data[[dir]]))
  data[[spd]][dnu] <- NA
  data[[dir]][dnu] <- NA

  # figure out the wind speed bins ----
  if (missing(spdseq)){
    spdseq <- seq(spdmin,spdmax,spdres)
  } else {
    if (debug >0){
      cat("Using custom speed bins \n")
    }
  }
  # get some information about the number of bins, etc.
  n.spd.seq <- length(spdseq)
  n.colors.in.range <- n.spd.seq - 1

  # create the color map
  spd.colors <- colorRampPalette(brewer.pal(min(max(3,
                                                    n.colors.in.range),
                                                min(9,
                                                    n.colors.in.range)),                                               
                                            palette))(n.colors.in.range)

  if (max(data[[spd]],na.rm = TRUE) > spdmax){    
    spd.breaks <- c(spdseq,
                    max(data[[spd]],na.rm = TRUE))
    spd.labels <- c(paste(c(spdseq[1:n.spd.seq-1]),
                          '-',
                          c(spdseq[2:n.spd.seq])),
                    paste(spdmax,
                          "-",
                          max(data[[spd]],na.rm = TRUE)))
    spd.colors <- c(spd.colors, "grey50")
  } else{
    spd.breaks <- spdseq
    spd.labels <- paste(c(spdseq[1:n.spd.seq-1]),
                        '-',
                        c(spdseq[2:n.spd.seq]))    
  }
  data$spd.binned <- cut(x = data[[spd]],
                         breaks = spd.breaks,
                         labels = spd.labels,
                         ordered_result = TRUE)
  # clean up the data
  data. <- na.omit(data)

  # figure out the wind direction bins
  dir.breaks <- c(-dirres/2,
                  seq(dirres/2, 360-dirres/2, by = dirres),
                  360+dirres/2)  
  dir.labels <- c(paste(360-dirres/2,"-",dirres/2),
                  paste(seq(dirres/2, 360-3*dirres/2, by = dirres),
                        "-",
                        seq(3*dirres/2, 360-dirres/2, by = dirres)),
                  paste(360-dirres/2,"-",dirres/2))
  # assign each wind direction to a bin
  dir.binned <- cut(data[[dir]],
                    breaks = dir.breaks,
                    ordered_result = TRUE)
  levels(dir.binned) <- dir.labels
  data$dir.binned <- dir.binned

  # Run debug if required ----
  if (debug>0){    
    cat(dir.breaks,"\n")
    cat(dir.labels,"\n")
    cat(levels(dir.binned),"\n")       
  }  

  # deal with change in ordering introduced somewhere around version 2.2
  if(packageVersion("ggplot2") > "2.2"){    
    cat("Hadley broke my code\n")
    data$spd.binned = with(data, factor(spd.binned, levels = rev(levels(spd.binned))))
    spd.colors = rev(spd.colors)
  }

  # create the plot ----
  p.windrose <- ggplot(data = data,
                       aes(x = dir.binned,
                           fill = spd.binned)) +
    geom_bar() + 
    scale_x_discrete(drop = FALSE,
                     labels = waiver()) +
    coord_polar(start = -((dirres/2)/360) * 2*pi) +
    scale_fill_manual(name = "Wind Speed (m/s)", 
                      values = spd.colors,
                      drop = FALSE) +
    #theme_bw() +
    theme(axis.title.x = element_blank(),
          #panel.border = element_rect(colour = "blank"),
          panel.grid.major = element_line(colour="grey65"))

  # adjust axes if required
  if (!is.na(countmax)){
    p.windrose <- p.windrose +
      ylim(c(0,countmax))
  }

  # print the plot
  print(p.windrose)  

  # return the handle to the wind rose
  return(p.windrose)
}

# %%
p2 <- plot.windrose(data=df_Wind, spd = df_Wind$spd,
                   dir = df_Wind$dir,
                   spdseq = c(0,1,2,3,4,5,6)) +
                   ggtitle("Vientos Diurnos (6AM-6PM) - Metano en Corrales") # for the main title
p2

# %%
install.packages('oce', repos='http://cran.us.r-project.org')
# Out:
# Warning message:
# “unable to access index for repository http://cran.us.r-project.org/src/contrib:
#   internet routines cannot be loaded”Warning message:
# “package ‘oce’ is not available (for R version 3.4.1)”

# %%
require(oce)
n <- 50
x <- 1:n
y <- rnorm(n=n)
y[n/2] <- 10                    # 10 standard deviations
plot(x, y, type='l')
lines(x, despike(y), col='red')
lines(x, despike(y, reference="smooth"), col='darkgreen')
lines(x, despike(y, reference="trim", min=-3, max=3), col='blue')
legend("topright", lwd=1, col=c("black", "red", "darkgreen", "blue"),
       legend=c("raw", "median", "smooth", "trim"))

# add a spike to a CTD object
data(ctd)
plot(ctd)
T <- ctd[["temperature"]]
T[10] <- T[10] + 10
ctd[["temperature"]] <- T
CTD <- despike(ctd)
plot(CTD)
# Out:
# Loading required package: oce
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘oce’”
# Error in xy.coords(x, y): could not find function "despike"
# Traceback:
#
# 1. lines(x, despike(y), col = "red")
# 2. lines.default(x, despike(y), col = "red")
# 3. plot.xy(xy.coords(x, y), type = type, ...)
# 4. xy.coords(x, y)
# plot without title

# %%
install.packages("devtools", repos="http://cran.itam.mx")
# Out:
# Warning message:
# “unable to access index for repository http://cran.itam.mx/src/contrib:
#   internet routines cannot be loaded”Warning message:
# “package ‘devtools’ is not available (for R version 3.4.1)”

# %%
install.packages("ggthemes", dependencies=TRUE, repos="https://cran.itam.mx")
# Out:
# Warning message:
# “unable to access index for repository https://cran.itam.mx/src/contrib:
#   internet routines cannot be loaded”Warning message:
# “package ‘ggthemes’ is not available (for R version 3.4.1)”

# %%
library(oce)
# Out:
# Error in library(oce): there is no package called ‘oce’
# Traceback:
#
# 1. library(oce)
# 2. stop(txt, domain = NA)
